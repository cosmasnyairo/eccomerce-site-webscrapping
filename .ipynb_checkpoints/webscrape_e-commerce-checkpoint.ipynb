# %%
import requests
from bs4 import BeautifulSoup

# %%
data=[]
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}
base_url='https://www.jumia.co.ke/catalog/?q=shirts&page='

# load the first 3 pages
page_nr=4
for i, page in enumerate(range(1,page_nr,1)):
    print(i, base_url+str(page)) 
    r=requests.get(base_url+str(page),headers=headers)
    c=r.content
    soup=BeautifulSoup(c, 'html.parser')
    all=soup.find_all('div', {'class':'sku -gallery -validate-size'})
    for a in all:
        entry={}
        try:
            title =a.find_all('span',{'class': 'name'})[0].text
            entry['Title']=title
        except:
            entry['Title']=None
        try:
            brand =a.find_all('span',{'class': 'brand'})[0].text
            entry['Brand']=brand
        except:
            entry['Brand']=None
        try:
            price= a.find('span', {'class': 'price'}).text
            entry['Price']=price
        except:
            entry['Price']=None
        for ratings in a.find_all('div', {'class':'total-ratings'}):
            entry['Ratings']=ratings.text[1]
        try:
            sizes=a.find_all('span', {'class': 'js-link sku-size'})
            sizes_list=[]
            for i in sizes:
                sizes_list.append(i.text)
            entry['Sizes']=sizes_list
        except:
            entry['Sizes']=None
        try:
            produrl = a.find('a', {'class': 'link'})['href']
            entry['Product Url']=produrl
        except:
            entry['Product Url']=None
        try:
            img_url= a.find('img', {'class': 'lazy image'})['data-src']
            entry['Image Url']=img_url
        except:
            entry['Image Url']=None
        data.append(entry)
# Out:
# 0 https://www.jumia.co.ke/catalog/?q=shirts&page=1
# 1 https://www.jumia.co.ke/catalog/?q=shirts&page=2
# 2 https://www.jumia.co.ke/catalog/?q=shirts&page=3

# %%
import pandas
df=pandas.DataFrame(data)

# %%
df
# Out:
#                                                  Title          Brand  \
# 0    Men's new single-breasted fashion slim short-s...       Fashion
# 1          2-in-1 Men's Short Sleeve Shorts Set - Blue       Fashion
# 2    Men's Classic Long Sleeve Cotton Plaid Dress S...       Fashion
# 3          2-in-1 Men's Short Sleeve Shorts Set - Blue       Fashion
# 4    White 3 In 1 Lux Premium Cotton Comfortable Ve...  Lux Premiums
# ..                                                 ...            ...
# 104       Men's Short Sleeve T-Shirt sailboat  - green       Generic
# 105     Men's Short Sleeve T-Shirt Star pattern - grey       Generic
# 106            Men's long sleeve t-shirt camel - black       Generic
# 107                Navy Blue Official Shirt - Slim fit       Fashion
# 108                     Navy Mens Cargo Pockets Shorts      Zecchino
#
#                        Price                                 Sizes  \
# 0                 KSh 1,225                        [M, L, XL, XXL]
# 1                 KSh 1,276           [M, L, XL, XXL, XXXL, xxxxl]
# 2                   KSh 898               [S, M, L, XL, XXL, XXXL]
# 3    KSh 1,190  - KSh 1,200           [M, L, XL, XXL, XXXL, xxxxl]
# 4                   KSh 528                        [M, L, XL, XXL]
# ..                       ...                                   ...
# 104                 KSh 699                  [M, L, XL, XXL, XXXL]
# 105                 KSh 699                  [M, L, XL, XXL, XXXL]
# 106                 KSh 799   [M, L, XL, XXL, XXXL, xxxxxl, xxxxl]
# 107               KSh 1,290               [S, M, L, XL, XXL, XXXL]
# 108                 KSh 720                           [28, 30, 32]
#
#                                            Product Url  \
# 0    https://www.jumia.co.ke/fashion-mens-new-singl...
# 1    https://www.jumia.co.ke/fashion-2-in-1-mens-sh...
# 2    https://www.jumia.co.ke/fashion-mens-classic-l...
# 3    https://www.jumia.co.ke/fashion-2-in-1-mens-sh...
# 4    https://www.jumia.co.ke/lux-premiums-white-3-i...
# ..                                                 ...
# 104  https://www.jumia.co.ke/generic-mens-short-sle...
# 105  https://www.jumia.co.ke/generic-mens-short-sle...
# 106  https://www.jumia.co.ke/generic-mens-long-slee...
# 107  https://www.jumia.co.ke/fashion-navy-blue-offi...
# 108  https://www.jumia.co.ke/zecchino-navy-mens-car...
#
#                                              Image Url Ratings
# 0    https://ke.jumia.is/Md1Mk2AMQXJFgrgi8TP-13g982...     NaN
# 1    https://ke.jumia.is/P-SHmZNsLCRDYy9svMjHkhAPiM...       3
# 2    https://ke.jumia.is/C41CqSUH0pqcBdkui-0tkrhKkM...       2
# 3    https://ke.jumia.is/qYFKZywlCBO65CHmj4Qq5XWbLL...       5
# 4    https://ke.jumia.is/wcZKuIWrv5cQmCWe4tJXpRQ1CU...       2
# ..                                                 ...     ...
# 104  https://ke.jumia.is/Sd3e7_0ZmN3x247e7gQXS2YBhv...     NaN
# 105  https://ke.jumia.is/nPlOR3yPp5smzkV4A0d8_sAVIw...     NaN
# 106  https://ke.jumia.is/2rttInIkbYyP8aelolirjyC4Op...       1
# 107  https://ke.jumia.is/mItEIJm2-uOJ6eyTcVYFAqcPy9...       5
# 108  https://ke.jumia.is/b7dViKKC6ec3fa87StiC_SYsHp...       6
#
# [109 rows x 7 columns]

# %%
df.to_csv('websrape.csv')
